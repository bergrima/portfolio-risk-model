# %%
import pandas as pd

# %%
df = pd.read_parquet(
    "C:/Users/Admin/Desktop/Portfolio Risk Model/data/raw/market_data.parquet"
)
gold = df[df["asset_id"] == "gold"].copy()

# %%
df2 = pd.read_parquet(
    "C:/Users/Admin/Desktop/Portfolio Risk Model/data/raw/market_data.parquet"
)
gold = df2[df2["asset_id"] == "gold"].copy()
# Out:
#            date asset_id  adjusted_close
# 608  2017-06-10     gold         10000.0
# 610  2017-06-11     gold         10000.0
# 612  2017-06-12     gold         10000.0
# 614  2017-06-13     gold         10000.0
# 616  2017-06-14     gold         10000.0
# ...         ...      ...             ...
# 6872 2026-08-02     gold       1294610.0
# 6875 2026-08-03     gold       1300635.0
# 6878 2026-08-05     gold       1291212.0
# 6881 2026-08-08     gold       1315632.0
# 6884 2026-08-09     gold       1313979.0
#
# [2145 rows x 3 columns]
